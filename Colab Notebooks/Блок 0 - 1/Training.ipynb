# %%
def narcissistic(value):
    str_val = str(value)
    len_str_val = len(str_val)
    list_val = []
    summa = 0
    for i in range(len_str_val):
      list_val.append(int(str_val[i]))
      print(list_val)    
      summa += int(list_val[i])**len_str_val
    return summa

res = narcissistic(548834)
print(res)

# %%
def narcissistic(value):
  return value == sum(int(x) ** len(str(value)) for x in str(value))
res = narcissistic(371)
print(res)
# Out:
# 2499

# %%
#Возвращает все самовлюбленные числа из заданного диапазона
def narcissistic1(value):
  return value == sum(int(x) ** len(str(value)) for x in str(value))

def check(x, y):
  listnum = []
  for k in range(x, y): #listnum.append(k) if narcissistic1(k) else listnum 
    if narcissistic1(k): listnum.append(k)
      #listnum.append(k) if narcissistic1(k)
  return listnum #(listnum.append(k) if narcissistic1(k) else listnum)
          
rangx, rangy = int(input('OT ')), int(input('DO '))
result = check(rangx, rangy)
print(result)
# Out:
# OT 1
# DO 5
# [1, 2, 3, 4]

# %%
def run(x, y):
 return x if x < y else y
  

a = 8
b = 6
print(run(a, b))
# Out:
# 6
