# %%
oleg_candies = 117
kate_candies = 131
peter_candies = 107

throw_away = (oleg_candies + kate_candies + peter_candies)

# %%
s1 = {}
print(type(s1))
s2 = {1,2,3}
print(type(s2))
s4 = {1:1,2:2,3:3}
print(type(s4))
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'dict'>
# stop

# %%
s1 = {'a', 'b', 'c', 'd', 'e'}
s1.add('hello')
print((s1))
# Out:
# {'d', 'e', 'c', 'b', 'hello', 'a'}

# %%
alpha_set = {'a', 'b', 'c', 'd', 'e'}
name = {'bad boy'}
print(type(name))
# Out:
# <class 'set'>

# %%
print(b'%(language)s has %(number)03d quote types.' %

      {b'language': b"Python", b"number": 2})
# Out:
# b'Python has 002 quote types.'

# %%
print(b'%(yt)s f fdsf %(2)d' %{b'yt':b'2', b'2':4})
# Out:
# b'2 f fdsf 4'

# %%
list6 = [3, 1, -10, 5, 11, 20, 1, -10]
list7 = list6.copy()
#list6 = list6.sort()
list_result = list6[::-1]
print(list7, list_result, list6.sort())
# Out:
# [3, 1, -10, 5, 11, 20, 1, -10] [-10, 1, 20, 11, 5, -10, 1, 3] None

# %%
def is_leap_year(x):
    return ((x % 400 == 0) or ((x % 4 == 0) and (x % 100 != 0)))
print(is_leap_year(int(input())))
# Out:
# 2002
# False

# %%
diagnosis_1, diagnosis_2, diagnosis_3 = 'no', 'yes', 'no'
print((diagnosis_1 == 'yes') or (diagnosis_2 == 'yes') or (diagnosis_3 == 'yes'))
print((diagnosis_1 or diagnosis_2 or diagnosis_3) == 'yes')
print(diagnosis_1 == 'yes' or diagnosis_2 == 'yes' or diagnosis_3 == 'yes')
print('yes' in (diagnosis_1, diagnosis_2, diagnosis_3))
print((diagnosis_1 == 'yes') | (diagnosis_2 == 'yes') | (diagnosis_3 == 'yes'))
print('yes' in [diagnosis_1, diagnosis_2, diagnosis_3])
print('yes' in diagnosis_1, diagnosis_2, diagnosis_3)
# Out:
# True
# False
# True
# True
# True
# True
# False yes no

# %%
num = str(int(input('N: ')))
print(int(num[0]) % 2 == 0)
# Out:
# N: -5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-72b1b1829c89> in <module>()
#       1 num = str(int(input('N: ')))
# ----> 2 print(int(num[0]) % 2 == 0)
#       3
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
list_1 = [1, 2]
 
list_2 = [1, 2, 3]
print(list_1, list_2)
val = list_2.pop()
print(list_1, list_2, val)
 
print(list_1 == list_2)
print(id(list_1) == id(list_2))
# Out:
# [1, 2] [1, 2, 3]
# [1, 2] [1, 2] 3
# True
# False

# %%
phone = ''
print(phone is not None)
# Out:
# True

# %%
is_rainy = True  # дождь будет

if is_rainy:    
    print("Take an umbrella") # брать зонт
else:
    print("Don't take an umbrella") # не брать зонт
# Out:
# Take an umbrella

# %%
mx = 0
s = 0
x = int(input())
if x < 0:
        s = x

b = 7
b /= b

if x > mx:
    mx = x

print(s)
print(mx)
# Out:
# 5
# 0
# 5

# %%
in1 = input('num1')
try:
  num1 = int(in1)
  print("You entered", num1)
except ValueError as e:
  print(e)
  print("LOSE! You entered a wrong number")
else:
  print("WOW! You entered a right number")
finally:
  print("Exit")
# Out:
# num1-3
# You entered -3
# WOW! You entered a right number
# Exit

# %%
def are_both_odd(A, B):
    return ((A and B) % 2 != 0)

# %%
x = int(input('x= '))
y = int(input('y= '))
if x > 0 and y > 0:
  print('1 First')
if x < 0 and y > 0:
  print('2 Second')
if x < 0 and y < 0:
  print('3 Third')
if x > 0 and y < 0:
  print('4 Fourth')
# Out:
# x= 0
# y= 0

# %%
a = int(input('a= '))
if a == 10:
    print('a equals 10') # a равно 10
elif a < 10:
    print('a is less than 10') # a меньше 10
else:
    print('a is more than 10') # a больше 10
# Out:
# a= 12
# a is more than 10

# %%
a, b = 10, 15
result = (b, a)[a > b]
print(result)
# Out:
# 15

# %%
a, b, c = 44, 41, 42
result = (False, True)[[a, b, c] != range(0,45)]
print(result, a, b, c)
# Out:
# False 44 41 42
