# %%
lst=[90, 230, 23]
lst.extend([30])
print(lst)
# Out:
# [90, 230, 23, 30]

# %%
my_list= [5, 9, 19]  # определяем итерируемый объект
for element in my_list: # подставляем его в шаблон для цикла и записываем имя переменной, которое будет использовано для каждого элемента этого объекта. В данном случае это element
    print('Element', element) # записываем необходимые действия в тело цикла
# Out:
# Element 5
# Element 9
# Element 19

# %%
lst = [98, 24, 23, 12, 3]
S = 1
for per in lst:
  S *= per
  print(S)
# Out:
# 98
# 2352
# 54096
# 649152
# 1947456

# %%
P = 1
N = 5
for i in range(1, N+1):
  print("Current S: ", P) #выводим значение суммы на текущем шаге
  print("Current number: ", i) #выводим текущее число
  P *= i  #суммируем текущее число i и перезаписываем значение суммы, равносильно S = S + i
  print("Sum after addition: ", P) #выводим значение суммы после сложения
  print("---") #выводим строчку для визуального разделения результатов
print("Answer: sum = ", P) #выводим ответ в формате ответ: сумма равна =
# Out:
# Current S:  1
# Current number:  1
# Sum after addition:  1
# ---
# Current S:  1
# Current number:  2
# Sum after addition:  2
# ---
# Current S:  2
# Current number:  3
# Sum after addition:  6
# ---
# Current S:  6
# Current number:  4
# Sum after addition:  24
# ---
# Current S:  24
# Current number:  5
# Sum after addition:  120
# ---
# Answer: sum =  120

# %%
n = 10
print('n=', n)
for i in range(n+1):
  print('*' * i)
# Out:
# n= 10
#
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]
location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}
#создаём цикл по списку мест, которые хотим посетить
for place in places: #place — текущее название места
    country = location[place] #получаем страну из словаря location по ключу
    if country != 'Russia': #сравниваем название стран
        places[place] = 'Unavailable' #помечаем место как недоступное
print(places) #выводим результирующий список
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c8c87c78cf9e> in <module>()
#      19     country = location[place] #получаем страну из словаря location по ключу
#      20     if country != 'Russia': #сравниваем название стран
# ---> 21         places[place] = 'Unavailable' #помечаем место как недоступное
#      22 print(places) #выводим результирующий список
#
# TypeError: list indices must be integers or slices, not str

# %%
my_list = []
for number in range(0, 10):
    my_list.append(number**2)
print(my_list)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
my_list = [1]
for i in range(10):
    my_list.append(my_list[i] * 2)
print(my_list)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
word_list = ['My', 'name', 'is', 'Anatoliy']
S = ''
for i in word_list:
  S += i
  S += " "
  print(S)
# Out:
# My
# My name
# My name is
# My name is Anatoliy

# %%
num_list = [1, 10, 3, -5]
num_list.sort()
print(num_list)
# Out:
# [-5, 1, 3, 10]

# %%
my_list = list(range(0, 100, 3))
x = 0
for i in my_list:
  if i % 2 == 0:
    x += 1
print(x)
# Out:
# 17

# %%
my_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another']
xx = 0
for i in my_list:
  if type(i) == str:
    xx += 1
print(xx)
# Out:
# 3

# %%
#Создаём цикл с условием, что длина списка больше 2
while len(lst) > 2:
    #Начало блока кода с телом цикла
    lst.pop(0) # Обновляем список, удаляя первый элемент в нём
    print(lst) # Выводим промежуточный результат
    #Конец блока кода с телом цикла
#Выводим на экран результирующий список
print('Result', lst)
# Out:
# [24, 23, 12, 3]
# [23, 12, 3]
# [12, 3]
# Result [12, 3]

# %%
weight = 19 #заданный вес входящего в лифт человека
max_weight = 300 #задаём грузоподъёмность
S = 0 #задаём суммарный вес людей в лифте
#создаём цикл, который будет работать, пока S не превысит max_weight 
while S < max_weight: #делай, пока...
    S += weight #увеличиваем суммарный вес, равносильно S = S + weight 
    print('Current sum weight', S) #выводим значение суммарного веса после обновления
print() #отделяем промежуточный вывод от результата пустой строкой
print('Overweight {} kg'.format(S-max_weight)) #выводим итоговое значение перевеса
# Out:
# Current sum weight 19
# Current sum weight 38
# Current sum weight 57
# Current sum weight 76
# Current sum weight 95
# Current sum weight 114
# Current sum weight 133
# Current sum weight 152
# Current sum weight 171
# Current sum weight 190
# Current sum weight 209
# Current sum weight 228
# Current sum weight 247
# Current sum weight 266
# Current sum weight 285
# Current sum weight 304
#
# Overweight 4 kg

# %%
sosud = 10 #litr
stak = 3.3 #
ob = 0
ost = 0
while ob <= sosud:
  ob += stak
  print(ob)
ost = ob - sosud
print(ost)
# Out:
# 3.3
# 6.6
# 9.899999999999999
# 13.2
# 3.1999999999999993

# %%
S = 0
num = 1
while S <= 500:
  S += num
  num += 1
  print("Still counting ...", num - 1, S)
print()
print(S)
# Out:
# Still counting ... 1 1
# Still counting ... 2 3
# Still counting ... 3 6
# Still counting ... 4 10
# Still counting ... 5 15
# Still counting ... 6 21
# Still counting ... 7 28
# Still counting ... 8 36
# Still counting ... 9 45
# Still counting ... 10 55
# Still counting ... 11 66
# Still counting ... 12 78
# Still counting ... 13 91
# Still counting ... 14 105
# Still counting ... 15 120
# Still counting ... 16 136
# Still counting ... 17 153
# Still counting ... 18 171
# Still counting ... 19 190
# Still counting ... 20 210
# Still counting ... 21 231
# Still counting ... 22 253
# Still counting ... 23 276
# Still counting ... 24 300
# Still counting ... 25 325
# Still counting ... 26 351
# Still counting ... 27 378
# Still counting ... 28 406
# Still counting ... 29 435
# Still counting ... 30 465
# Still counting ... 31 496
# Still counting ... 32 528
#
# 528

# %%
n = 0
S = 0
while S < 1000:
  n += 1
  S = n*n
  print(S, n)
print()
S = (n-1)*(n-1)
print (S, n-1)
# Out:
# 1 1
# 4 2
# 9 3
# 16 4
# 25 5
# 36 6
# 49 7
# 64 8
# 81 9
# 100 10
# 121 11
# 144 12
# 169 13
# 196 14
# 225 15
# 256 16
# 289 17
# 324 18
# 361 19
# 400 20
# 441 21
# 484 22
# 529 23
# 576 24
# 625 25
# 676 26
# 729 27
# 784 28
# 841 29
# 900 30
# 961 31
# 1024 32
#
# 961 31

# %%
# хорошо
n = 1
while True:  # в данной программе условие всегда True, цикл будет бесконечным
    print("New client !")
    n += 1
    if n > 10:  # условие, при достижении которого цикл while будет принудительно завершён
        break
# Out:
# New client !
# New client !
# New client !
# New client !
# New client !
# New client !
# New client !
# New client !
# New client !
# New client !

# %%
S = 0
i = 0
while True:
  i += 1
  S = i*i
  if S > 1000:
    print(S)
    break
  else:
    print('ewe')
# Out:
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# ewe
# 1024

# %%
i = 0
S = 1
while S < 1000:
  i += 1
  S *= i
print(S)
# Out:
# 5040

# %%
n = 1
k = 3
S = 0
i = 0
while 3 ** n < 1000:
  i += 1
  print(3**n, n, i)
  n += 1
print(3**n, n, i)
# Out:
# 3 1 1
# 9 2 2
# 27 3 3
# 81 4 4
# 243 5 5
# 729 6 6
# 2187 7 6

# %%
money = 1000
srok = 0
S = money
while S < 3000:
  S *= 1.08
  srok += 1
  print(srok, S)
# Out:
# 1 1080.0
# 2 1166.4
# 3 1259.7120000000002
# 4 1360.4889600000004
# 5 1469.3280768000004
# 6 1586.8743229440006
# 7 1713.8242687795207
# 8 1850.9302102818824
# 9 1999.0046271044332
# 10 2158.924997272788
# 11 2331.638997054611
# 12 2518.17011681898
# 13 2719.6237261644987
# 14 2937.193624257659
# 15 3172.169114198272

# %%
hours = list(range(9, 24, 2))
minutes = list(range(0, 60, 15))
for hour in hours:
  for minute in minutes:
    print('Alarm is set {}:{}'.format(hour, minute))
# Out:
# Alarm is set 9:0
# Alarm is set 9:15
# Alarm is set 9:30
# Alarm is set 9:45
# Alarm is set 11:0
# Alarm is set 11:15
# Alarm is set 11:30
# Alarm is set 11:45
# Alarm is set 13:0
# Alarm is set 13:15
# Alarm is set 13:30
# Alarm is set 13:45
# Alarm is set 15:0
# Alarm is set 15:15
# Alarm is set 15:30
# Alarm is set 15:45
# Alarm is set 17:0
# Alarm is set 17:15
# Alarm is set 17:30
# Alarm is set 17:45
# Alarm is set 19:0
# Alarm is set 19:15
# Alarm is set 19:30
# Alarm is set 19:45
# Alarm is set 21:0
# Alarm is set 21:15
# Alarm is set 21:30
# Alarm is set 21:45
# Alarm is set 23:0
# Alarm is set 23:15
# Alarm is set 23:30
# Alarm is set 23:45

# %%
str_list = ['text', 'morning', 'notepad', 'television', 'ornament']
count = 0
for text in str_list:
  for symbol in text:
    print(text, symbol)
    if symbol == 'e':
      count += 1
print(count)
# Out:
# text t
# text e
# text x
# text t
# morning m
# morning o
# morning r
# morning n
# morning i
# morning n
# morning g
# notepad n
# notepad o
# notepad t
# notepad e
# notepad p
# notepad a
# notepad d
# television t
# television e
# television l
# television e
# television v
# television i
# television s
# television i
# television o
# television n
# ornament o
# ornament r
# ornament n
# ornament a
# ornament m
# ornament e
# ornament n
# ornament t
# 5

# %%
str_list = ['text', 'morning', 'notepad', 'television', 'ornament'] #заданный список строк
count = 0 #задаём начальное количество символов 'e'
#создаём цикл по элементам списка str_list
for text in str_list:
    #увеличиваем количество символов 'e' 
    count += text.count('e') #.count() считает, сколько раз символ встречается в строке text
print('Count symbol "e":', count) #выводим результат
# Out:
# Count symbol "e": 5

# %%
text_list = [
    'afbaad',
    'faaf',
    'afaga',
    'agag'
]
count = 0
for text in text_list:
  count += text.count('a')
print('a = :', count)
# Out:
# a = : 10

# %%
random_matrix = [
    [9, 2, 1],
    [2, 5, 3],
    [4, 8, 5]
] #заданная матрица
max_value_rows = [] #задаём пустой список с минимальными значениями строк
#создаём цикл по строкам матрицы random_matrix 
for row in random_matrix: #row — текущая строка таблицы
    max_value = row[0] #начальное значение кандидата на минимум
    #создаём цикл по элементам списка row
    for elem in row: #elem — текущий элемент из списка row
        #проверяем условие, что текущий элемент меньше кандидата на минимум
        if elem > max_value: #если условие выполняется,
            max_value = elem #заменяем кандидата на минимум
    max_value_rows.append(max_value) #добавляем полученный минимум строки в список
print("Maximal elements:", max_value_rows)
# Out:
# Maximal elements: [9, 5, 8]

# %%
scores = [
    [0.5, 0.6, 0.6, 0.65, 0.3],
    [0.55, 0.7, 0.9, 0.5, 0.5]
]
print(scores[1][2])
# Out:
# 0.5

# %%
count = 0
for i in range(5):
    for j in range(4):
        count += 1
print(count)
# Out:
# 20

# %%
scores = [
    [0.5, 0.6, 0.6, 0.65, 0.3],
    [0.55, 0.7, 0.9, 0.5, 0.5]
]
scores_lst = []
for row in scores:
    for score in row:
        scores_lst.append(score)
print(scores_lst)
# Out:
# [0.5, 0.6, 0.6, 0.65, 0.3, 0.55, 0.7, 0.9, 0.5, 0.5]

# %%
itest_matrix1 = [
    [1, 2, 3],
    [7, -1, 2],
    [123, 2, -1]
]
test_matrix2 = [
    [1, 2, 3],
    [7, -1, 2],
    [123, 2, -1],
    [123, 5, 1]
]
for i in test_matrix1:
  i = test_matrix1.count()
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-39158201a0fc> in <module>()
#      11 ]
#      12 for i in test_matrix1:
# ---> 13   i = test_matrix1.count()
#      14   print(i)
#
# TypeError: count() takes exactly one argument (0 given)

# %%
str_list = ['text', 'morning', 'notepad', 'television', 'ornament']
for text in str_list:
  dict1 = {text:text.count('t')}
  dict1[text] += 1
  print(dict1)
# Out:
# {'text': 3}
# {'morning': 1}
# {'notepad': 2}
# {'television': 2}
# {'ornament': 2}
