# %%
tpl1 = tuple([255] )
print(tpl1)
# Out:
# (255,)

# %%
numbers = input('d ' )
numbers_split = numbers.split() 
print(numbers_split.count(5)) 
numbers_numbers = numbers_split.count('5')
print(numbers_numbers)
# Out:
# d 1 2 3 4 5
# 0
# 1

# %%
print(2**38)
# Out:
# 274877906944
